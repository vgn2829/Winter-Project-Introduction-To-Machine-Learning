# %% [markdown]
# importing libraries

# %%
import numpy as np  ;
import matplotlib.pyplot as plt ;
import pandas as pd
from sklearn.datasets import load_iris

# %% [markdown]
# #  Q1. Using NumPy, create a 3D array of shape (4, 4, 4) filled with random numbers between 1 and 100. Find the z score normalisation of each element of the array.

# %%
arr= np.random.randint(1,100,(4,4,4))
print(arr)
# Out:
# [[[48 73 61 38]
#   [37 19 28 78]
#   [33 19 45 66]
#   [13 53 32 29]]
#
#  [[30 84 25 38]
#   [58 75 50 82]
#   [48  6 12 56]
#   [67 12 36 65]]
#
#  [[34 36 97 33]
#   [75 13  8 41]
#   [12 85 21 68]
#   [61 88 41 82]]
#
#  [[64  4 24 36]
#   [48  1 56 77]
#   [11 34 87 52]
#   [33 41 26 94]]]

# %%
mean =np.mean(arr)
standard_dev=np.std(arr)
z_score = (arr-mean)/standard_dev
print(z_score)
# Out:
# [[[ 0.10713146  1.09794269  0.6223533  -0.28919303]
#   [-0.32882548 -1.04220956 -0.68551752  1.29610494]
#   [-0.48735527 -1.04220956 -0.01176588  0.82051555]
#   [-1.28000425  0.30529371 -0.52698772 -0.64588507]]
#
#  [[-0.60625262  1.53389963 -0.80441487 -0.28919303]
#   [ 0.50345596  1.17720759  0.18639636  1.45463473]
#   [ 0.10713146 -1.5574314  -1.3196367   0.42419106]
#   [ 0.860148   -1.3196367  -0.36845793  0.7808831 ]]
#
#  [[-0.44772282 -0.36845793  2.04912147 -0.48735527]
#   [ 1.17720759 -1.28000425 -1.4781665  -0.17029568]
#   [-1.3196367   1.57353208 -0.96294466  0.89978045]
#   [ 0.6223533   1.69242943 -0.17029568  1.45463473]]
#
#  [[ 0.74125065 -1.6366963  -0.84404731 -0.36845793]
#   [ 0.10713146 -1.75559364  0.42419106  1.25647249]
#   [-1.35926915 -0.44772282  1.65279698  0.26566126]
#   [-0.48735527 -0.17029568 -0.76478242  1.93022412]]]

# %% [markdown]
# # Q2. Using Pandas, filter the rows in the Iris dataset where the petal length is greater than 3.0, and display the filtered data

# %%
iris = load_iris(as_frame=True)
iris_data = iris.frame

filtered_data = iris_data[iris_data["petal length (cm)"]>3.0]
print(filtered_data)
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 50                 7.0               3.2                4.7               1.4
# 51                 6.4               3.2                4.5               1.5
# 52                 6.9               3.1                4.9               1.5
# 53                 5.5               2.3                4.0               1.3
# 54                 6.5               2.8                4.6               1.5
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 50        1
# 51        1
# 52        1
# 53        1
# 54        1
# ..      ...
# 145       2
# 146       2
# 147       2
# 148       2
# 149       2
#
# [99 rows x 5 columns]

# %% [markdown]
# # Q3. Using Matplotlib, plot a line graph showing the trend of a numerical dataset. Customize the plot with title, axis labels, and a legend.

# %%
a = [1,2,3,4,5,6,7] ;
b = [10,12,28,34,98,115,134] ;

# Create the plot
plt.plot(a,b,label='Data Trend',color = "red",marker = '*') ;

# Title, axis labels and legend
plt.title('Trend of Numerical Dataset')
plt.xlabel('x') ;
plt.ylabel('y') ;
plt.legend()

# Final graph
plt.show() ;

# %% [markdown]
# # Q4.Create a Pandas DataFrame with random values with at least 3 columns and perform the following operations: (i) Replace NaN values with the mean of the column. (ii) Sort the DataFrame based on any two columns.

# %%
np.random.seed(52)
data = {
    'Column1': np.random.randint(1, 50, 10),
    'Column2': np.random.rand(10),
    'Column3': [np.nan, 5, 10, np.nan, 20, 25, np.nan, 40, 50, np.nan]
}
df=pd.DataFrame(data)
print(df)
# Out:
#    Column1   Column2  Column3
# 0       29  0.053890      NaN
# 1       12  0.960654      5.0
# 2       14  0.980429     10.0
# 3       24  0.521128      NaN
# 4       23  0.636553     20.0
# 5       29  0.764757     25.0
# 6       33  0.764955      NaN
# 7        6  0.417686     40.0
# 8       43  0.768805     50.0
# 9       12  0.423202      NaN

# %%
sorted_df = df.sort_values(by=['Column1'], ascending=[True])
print(sorted_df)
# Out:
#    Column1   Column2  Column3
# 7        6  0.417686     40.0
# 1       12  0.960654      5.0
# 9       12  0.423202      NaN
# 2       14  0.980429     10.0
# 4       23  0.636553     20.0
# 3       24  0.521128      NaN
# 0       29  0.053890      NaN
# 5       29  0.764757     25.0
# 6       33  0.764955      NaN
# 8       43  0.768805     50.0

# %% [markdown]
# # Q5. Using NumPy, calculate the dot product of two matrices and find the determinant of the resulting matrix.

# %%
mat1=[[1,2],[4,5]]
mat2=[[5,4],[3,1]]
dot_product=np.dot(mat1,mat2)
print(dot_product)
det=np.linalg.det(dot_product)
print(det)
# Out:
# [[11  6]
#  [35 21]]
# 20.999999999999982

# %% [markdown]
# # Q6. With Pandas, group a DataFrame by a categorical column and calculate the sum of another numerical column for each group.

# %%
data = {
    'Column1': ['A','A','A','B','A','C','B','C','B','A','C'],
    'Column2': [2,3,5,1,7,8,7,8,5,2,1] ,

}
df=pd.DataFrame(data)

# %%
grouped_sum = df.groupby('Column1')['Column2'].sum()
print(grouped_sum)
# Out:
# Column1
# A    19
# B    13
# C    17
# Name: Column2, dtype: int64

# %% [markdown]
# # Q7. Using Matplotlib, create a histogram to show the distribution of a numerical dataset. Customize the number of bins and add grid lines for better readability.

# %%
#a random numerical dataset
data = np.random.randn(1000)

#a histogram
plt.hist(data, bins=16, color='blue')

# Add grid lines
plt.grid(True)

# Add labels and title
plt.xlabel('Scores')
plt.ylabel('Frequency')
plt.title('Histogram of Random Data')

#plot
plt.show()

# %% [markdown]
# # Q8. Using NumPy, create a 2D array and perform a slicing operation to extract a specific sub-array.

# %%
arr=np.random.randint(1,10,(2,10))
print(arr)
new=arr[:,1:5]
print(new)
# Out:
# [[8 5 7 8 8 8 5 3 6 5]
#  [1 2 3 6 3 7 7 6 1 7]]
# [[5 7 8 8]
#  [2 3 6 3]]

# %% [markdown]
# # Q9. Using Pandas, perform a merge operation between two DataFrames based on a common column for dataset of your choice.

# %%
# DataFrame 1
students_df = pd.DataFrame({
    'StudentID': [1,2,3],
    'Name': ['A','B','C'],

})

# DataFrame 2
courses_df = pd.DataFrame({
    'StudentID': [1,2,3],
    'Course': ['eng', 'phy', 'che'],
    'Grade': ['A', 'B', 'A']
})

print( students_df)
print(courses_df)
# Out:
#    StudentID Name
# 0          1    A
# 1          2    B
# 2          3    C
#    StudentID Course Grade
# 0          1    eng     A
# 1          2    phy     B
# 2          3    che     A

# %%
merged_df = pd.merge(students_df, courses_df, on='StudentID', how='inner')
print(merged_df)
# Out:
#    StudentID Name Course Grade
# 0          1    A    eng     A
# 1          2    B    phy     B
# 2          3    C    che     A

# %% [markdown]
# # Q10. Using Matplotlib, create a scatter plot comparing two numerical variables in the dataset of your choice. Customize the plot by changing the color and shape of the data points.

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.random.rand(333)
y = np.random.rand(333)

plt.scatter(x, y, c='orange', marker='*')  # Red triangles

plt.title('Scatter Plot')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')

#the plot
plt.show()
