# %%
#1
import numpy as np
# 3d array
arr_3d = np.random.randint(0,101,(4,4,4))
# Z score normalisation
mean = np.mean(arr_3d)
std_dev = np.std(arr_3d)

z_score = (arr_3d-mean)/std_dev
print("3D Array: \n", arr_3d)
print("\nZ score normalisation:\n",z_score)
# Out:
# 3D Array:
#  [[[ 88  92  11  90]
#   [ 89  47  15  41]
#   [  1  15  82  30]
#   [ 41   8  23  40]]
#
#  [[ 15  19  35  70]
#   [  3  26  12  59]
#   [ 33  91  94  73]
#   [ 33   3  30  85]]
#
#  [[ 75  91  67   4]
#   [ 10  49  19   1]
#   [ 40  78  48  56]
#   [ 81  99  16  92]]
#
#  [[ 97  41  13 100]
#   [  9  37  46  71]
#   [ 41  54  43  58]
#   [ 61  68  97  78]]]
#
# Z score normalisation:
#  [[[ 1.25917559e+00  1.38821840e+00 -1.22489859e+00  1.32369700e+00]
#   [ 1.29143629e+00 -6.35132603e-02 -1.09585578e+00 -2.57077482e-01]
#   [-1.54750563e+00 -1.09585578e+00  1.06561137e+00 -6.11945223e-01]
#   [-2.57077482e-01 -1.32168070e+00 -8.37770148e-01 -2.89338186e-01]]
#
#  [[-1.09585578e+00 -9.66812963e-01 -4.50641704e-01  6.78482924e-01]
#   [-1.48298422e+00 -7.40988037e-01 -1.19263789e+00  3.23615184e-01]
#   [-5.15163112e-01  1.35595770e+00  1.45273981e+00  7.75265035e-01]
#   [-5.15163112e-01 -1.48298422e+00 -6.11945223e-01  1.16239348e+00]]
#
#  [[ 8.39786442e-01  1.35595770e+00  5.81700813e-01 -1.45072352e+00]
#   [-1.25715930e+00  1.00814699e-03 -9.66812963e-01 -1.54750563e+00]
#   [-2.89338186e-01  9.36568553e-01 -3.12525567e-02  2.26833073e-01]
#   [ 1.03335066e+00  1.61404333e+00 -1.06359507e+00  1.38821840e+00]]
#
#  [[ 1.54952192e+00 -2.57077482e-01 -1.16037719e+00  1.64630403e+00]
#   [-1.28942000e+00 -3.86120297e-01 -9.57739640e-02  7.10743628e-01]
#   [-2.57077482e-01  1.62311665e-01 -1.92556075e-01  2.91354480e-01]
#   [ 3.88136591e-01  6.13961517e-01  1.54952192e+00  9.36568553e-01]]]

# %%
#2
import pandas as pd
from sklearn.datasets import load_iris

iris = load_iris(as_frame=True)
iris_data = iris.frame

desired_data = iris_data[iris_data["petal length (cm)"]>3.0]
print(desired_data)
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 50                 7.0               3.2                4.7               1.4
# 51                 6.4               3.2                4.5               1.5
# 52                 6.9               3.1                4.9               1.5
# 53                 5.5               2.3                4.0               1.3
# 54                 6.5               2.8                4.6               1.5
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 50        1
# 51        1
# 52        1
# 53        1
# 54        1
# ..      ...
# 145       2
# 146       2
# 147       2
# 148       2
# 149       2
#
# [99 rows x 5 columns]

# %%
#3
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0,10,500)
y = np.cos(x)

plt.figure(figsize=(8,5))
plt.plot(x,y,label='cos(x)',color='blue' , linewidth=2)

plt.title('Cosine function' , fontsize=16)
plt.xlabel('X-axis' , fontsize=12)
plt.ylabel('Y-axis' , fontsize=12)
plt.legend(loc='upper right', fontsize=10)
plt.grid(alpha=0.3)

plt.show()

# %%
#4
import pandas as pd
import numpy as np

# random values and some NaN
np.random.seed(42)  # For reproducibility
data = {
    'A': np.random.randn(10),
    'B': np.random.randn(10),
    'C': np.random.randn(10)
}
df = pd.DataFrame(data)

# Introducing some NaN values
df.loc[[2, 5, 7], 'A'] = np.nan
df.loc[[1, 6], 'B'] = np.nan
df.loc[[0, 4, 8], 'C'] = np.nan

print("Original DataFrame:")
print(df)

# Replacing NaN values with the mean of their respective columns
df.fillna(df.mean(), inplace=True)

#DataFrame after replacing NaN
print("\nDataFrame after replacing NaN with column means:")
print(df)

# Sorting the DataFrame based on columns 'A' and 'B'
df_sorted = df.sort_values(by=['A', 'B']).reset_index(drop=True)

# Display sorted DataFrame
print("\nSorted DataFrame (by 'A' and 'B'):")
print(df_sorted)
# Out:
# Original DataFrame:
#           A         B         C
# 0  0.496714 -0.463418       NaN
# 1 -0.138264       NaN -0.225776
# 2       NaN  0.241962  0.067528
# 3  1.523030 -1.913280 -1.424748
# 4 -0.234153 -1.724918       NaN
# 5       NaN -0.562288  0.110923
# 6  1.579213       NaN -1.150994
# 7       NaN  0.314247  0.375698
# 8 -0.469474 -0.908024       NaN
# 9  0.542560 -1.412304 -0.291694
#
# DataFrame after replacing NaN with column means:
#           A         B         C
# 0  0.496714 -0.463418 -0.362723
# 1 -0.138264 -0.803503 -0.225776
# 2  0.471375  0.241962  0.067528
# 3  1.523030 -1.913280 -1.424748
# 4 -0.234153 -1.724918 -0.362723
# 5  0.471375 -0.562288  0.110923
# 6  1.579213 -0.803503 -1.150994
# 7  0.471375  0.314247  0.375698
# 8 -0.469474 -0.908024 -0.362723
# 9  0.542560 -1.412304 -0.291694
#
# Sorted DataFrame (by 'A' and 'B'):
#           A         B         C
# 0 -0.469474 -0.908024 -0.362723
# 1 -0.234153 -1.724918 -0.362723
# 2 -0.138264 -0.803503 -0.225776
# 3  0.471375 -0.562288  0.110923
# 4  0.471375  0.241962  0.067528
# 5  0.471375  0.314247  0.375698
# 6  0.496714 -0.463418 -0.362723
# 7  0.542560 -1.412304 -0.291694
# 8  1.523030 -1.913280 -1.424748
# 9  1.579213 -0.803503 -1.150994

# %%
#5
import numpy as np

matrix1 = np.random.randint(1, 10, size=(3, 3))
matrix2 = np.random.randint(1, 10, size=(3, 3))

product_matrix = np.dot(matrix1, matrix2)

determinant = np.linalg.det(product_matrix)

print("Matrix 1:")
print(matrix1)
print("\nMatrix 2:")
print(matrix2)
print("\nProduct Matrix:")
print(product_matrix)
print("\nDeterminant of the Product Matrix:")
print(determinant)
# Out:
# Matrix 1:
# [[1 8 2]
#  [6 4 9]
#  [8 6 8]]
#
# Matrix 2:
# [[1 2 6]
#  [7 7 9]
#  [8 3 6]]
#
# Product Matrix:
# [[ 73  64  90]
#  [106  67 126]
#  [114  82 150]]
#
# Determinant of the Product Matrix:
# -24030.000000000065

# %%
#6
import pandas as pd

# Create a dataframe
data = {
    'Column': ['Aman', 'Bittu', 'Aman', 'Bittu', 'Aman', 'Bittu', 'Chetan', 'Chetan'],
    'Values': [10, 20, 30, 40, 50, 60, 70, 80]
}

df = pd.DataFrame(data)


grouped = df.groupby('Column')['Values'].sum()

#result
print(grouped)
# Out:
# Column
# Aman       90
# Bittu     120
# Chetan    150
# Name: Values, dtype: int64

# %%
#7
import matplotlib.pyplot as plt
import numpy as np

#a random numerical dataset
data = np.random.randn(1000)

#a histogram
plt.hist(data, bins=20)

# Add grid lines
plt.grid(True)

# Add labels and title
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram of Random Data')

#plot
plt.show()

# %%
#8
import numpy as np

arr = np.random.randint(1, 10, size=(3, 3))

# Extract a sub-array
sub_arr = arr[1:, 1:]

print(arr)
print(sub_arr)
# Out:
# [[8 5 1]
#  [4 9 3]
#  [2 1 6]]
# [[9 3]
#  [1 6]]

# %%
#9
import pandas as pd

df1 = pd.DataFrame({'ID': [1, 2, 3],
                    'Name': ['Areen', 'Bittu', 'Chirag']})

df2 = pd.DataFrame({'ID': [2, 3, 1],
                    'Age': [25, 30, 28]})

# Merging on basis of ID
merged_df = pd.merge(df1, df2, on='ID')

print(merged_df)
# Out:
#    ID    Name  Age
# 0   4   Areen   28
# 1   2   Bittu   25
# 2   3  Chirag   30

# %%
#10
import matplotlib.pyplot as plt
import numpy as np

x = np.random.rand(350)
y = np.random.rand(350)

plt.scatter(x, y, c='green', marker='^')  # Red triangles

plt.title('Scatter Plot')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')

#the plot
plt.show()
